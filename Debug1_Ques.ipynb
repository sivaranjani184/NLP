# %% [markdown]
# # 1.OS Error

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 13.7/13.7 MB 8.4 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytoolconfig 1.2.5 requires typing-extensions>=4.4.0; python_version < "3.8", but you have typing-extensions 3.10.0.2 which is incompatible.
# astroid 2.14.2 requires typing-extensions>=4.0.0; python_version < "3.11", but you have typing-extensions 3.10.0.2 which is incompatible.
# asgiref 3.7.2 requires typing-extensions>=4; python_version < "3.11", but you have typing-extensions 3.10.0.2 which is incompatible.
# ...
#      ---------------------------------------- 82.8/82.8 kB 1.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 57.0/57.0 kB 2.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# # 2.Error: ModuleNotFoundError for TextBlob

# %%
#install pip install textblob
from textblob import TextBlob
blob = TextBlob("TextBlob is amazing.")
print(blob.sentiment)
# Out:
# Sentiment(polarity=0.6000000000000001, subjectivity=0.9)

# %% [markdown]
# # 3.AttributeError

# %%
from sklearn.feature_extraction.text import CountVectorizer
texts = ["Siva", "ranjani"]  # declared as strings
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texts)
print(X.toarray())
# Out:
# [[0 1]
#  [1 0]]

# %% [markdown]
# # 4.Attribute Error

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
print(stop_words[:10]) #in NLP to display the first 10 words from a predefined list of "stop words"
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']

# %% [markdown]
# # 5.ValueError

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
X = tfidf.fit_transform(["string1","string2"])
print(X.toarray())
# Out:
# [[1. 0.]
#  [0. 1.]]

# %% [markdown]
# # 6.NameError

# %%
from wordcloud import WordCloud,STOPWORDS
wc = WordCloud(stopwords=STOPWORDS)
